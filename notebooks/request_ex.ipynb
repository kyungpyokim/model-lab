# %%
import requests

url = 'http://localhost:8000'

res = requests.get(url)
print(res.status_code)
# Out:
# 200

# %%
from lib.utils.path import data_path

with open(data_path() / 'images' / 'bus.jpg', 'rb') as f:
    files = {'file': f}

    res = requests.post(url=f'{url}/upload_image', files=files)

    if res.status_code == 200:
        print(res.json())
# Out:
# {'message': '이미지를 저장했습니다.', 'filename': 'C:\\Workspaces\\model_lab\\data/images/20260318160249-bus.jpg', 'time': '20260318160249'}

# %%
import json

from lib.utils.path import data_path

with open(data_path() / 'images' / 'bus.jpg', 'rb') as f:
    files = {'file': f}

    res = requests.post(url=f'{url}/detect_image', files=files)

    if res.status_code == 200:
        print(json.dumps(res.json(), indent=4))
# Out:
# {
#     "message": "\uc774\ubbf8\uc9c0\ub97c \uc800\uc7a5\ud588\uc2b5\ub2c8\ub2e4.",
#     "filename": "C:\\Workspaces\\model_lab\\data/images/20260318164002-bus.jpg",
#     "time": "20260318164002",
#     "object_detection": [
#         {
#             "box": [
#                 0.0,
#                 229.37254333496094,
#                 806.08837890625,
#                 757.1253662109375
#             ],
#             "confidence": 0.9239633679389954,
#             "label": "bus"
#         },
#         {
#             "box": [
#                 222.466552734375,
#                 404.9287109375,
#                 345.4031677246094,
#                 861.6566772460938
#             ],
#             "confidence": 0.9126350283622742,
#             "label": "person"
#         },
#         {
#             "box": [
#                 47.68634796142578,
#                 399.2962951660156,
#                 239.3299102783203,
#                 903.02587890625
#             ],
#             "confidence": 0.9054479598999023,
#             "label": "person"
#         },
#         {
#             "box": [
#                 670.6502075195312,
#                 391.5212097167969,
#                 809.8085327148438,
#                 878.995849609375
#             ],
#             "confidence": 0.8699917793273926,
#             "label": "person"
#         },
#         {
#             "box": [
#                 0.13089609146118164,
#                 556.6618041992188,
#                 60.00251388549805,
#                 870.1117553710938
#             ],
#             "confidence": 0.5352139472961426,
#             "label": "person"
#         }
#     ]
# }

# %% [markdown]
# # 3. detect_image 테스트

# %%
import json

import requests

from lib.utils.path import data_path

url = 'http://localhost:8000'

with open(data_path() / 'images' / 'badugi.jpg', 'rb') as f:
    files = {'file': f}

    res = requests.post(url=f'{url}/clip_image', files=files)

    if res.status_code == 200:
        print(json.dumps(res.json(), indent=4))
# Out:
# {
#     "index": 0,
#     "classes": [
#         "dog",
#         "cat",
#         "pig"
#     ],
#     "probs": [
#         0.9800839424133301,
#         0.0031971146818250418,
#         0.01671903021633625
#     ]
# }

# %%
from mybot import mybot

print(mybot('안녕'))
# Out:
# 안녕! 반가워요. 오늘도 코드처럼 깔끔한 하루 되길 바래요.
#
# 아재개그 하나 섞어볼게요: 왜 개발자는 커피를 많이 마실까요? 자바(Java)라서요—루프 돌릴 때 필요한 게 다 커피에 담겨 있답니다.
#
# 필요한 게 있으면 말해줘요. 디버깅, 알고리즘, 공부 팁, 혹은 또 다른 아재개그도 준비되어 있습니다!

# %%
import requests

url = 'http://localhost:8080/chat'

data = {
    'message': '넌 누구니?'
}

res = requests.post(url, json=data)
if res.status_code == 200:
    print(res.json())
# Out:
# {'text': {'format': {'type': 'text'}, 'verbosity': 'medium'}}
