# %%
import requests

url = 'http://localhost:8000'

res = requests.get(url)
print(res.status_code)
# Out:
# 200

# %%
from lib.utils.path import data_path

with open(data_path() / 'images' / 'bus.jpg', 'rb') as f:
    files = {'file': f}

    res = requests.post(url=f'{url}/upload_image', files=files)

    if res.status_code == 200:
        print(res.json())
# Out:
# {'message': '이미지를 저장했습니다.', 'filename': 'C:\\Workspaces\\model_lab\\data/images/20260318160249-bus.jpg', 'time': '20260318160249'}

# %%
import json

from lib.utils.path import data_path

with open(data_path() / 'images' / 'bus.jpg', 'rb') as f:
    files = {'file': f}

    res = requests.post(url=f'{url}/detect_image', files=files)

    if res.status_code == 200:
        print(json.dumps(res.json(), indent=4))
# Out:
# {
#     "message": "\uc774\ubbf8\uc9c0\ub97c \uc800\uc7a5\ud588\uc2b5\ub2c8\ub2e4.",
#     "filename": "C:\\Workspaces\\model_lab\\data/images/20260318164002-bus.jpg",
#     "time": "20260318164002",
#     "object_detection": [
#         {
#             "box": [
#                 0.0,
#                 229.37254333496094,
#                 806.08837890625,
#                 757.1253662109375
#             ],
#             "confidence": 0.9239633679389954,
#             "label": "bus"
#         },
#         {
#             "box": [
#                 222.466552734375,
#                 404.9287109375,
#                 345.4031677246094,
#                 861.6566772460938
#             ],
#             "confidence": 0.9126350283622742,
#             "label": "person"
#         },
#         {
#             "box": [
#                 47.68634796142578,
#                 399.2962951660156,
#                 239.3299102783203,
#                 903.02587890625
#             ],
#             "confidence": 0.9054479598999023,
#             "label": "person"
#         },
#         {
#             "box": [
#                 670.6502075195312,
#                 391.5212097167969,
#                 809.8085327148438,
#                 878.995849609375
#             ],
#             "confidence": 0.8699917793273926,
#             "label": "person"
#         },
#         {
#             "box": [
#                 0.13089609146118164,
#                 556.6618041992188,
#                 60.00251388549805,
#                 870.1117553710938
#             ],
#             "confidence": 0.5352139472961426,
#             "label": "person"
#         }
#     ]
# }

# %% [markdown]
# # 3. detect_image 테스트

# %%
import json

import requests

from lib.utils.path import data_path

url = 'http://localhost:8000'

with open(data_path() / 'images' / 'badugi.jpg', 'rb') as f:
    files = {'file': f}

    res = requests.post(url=f'{url}/clip_image', files=files)

    if res.status_code == 200:
        print(json.dumps(res.json(), indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 with open(data_path() / 'images' / 'badugi.jpg', 'rb') as f:
#       8     files = {'file': f}
# ---> 10     res = requests.post(url=f'{url}/clip_image', files=files)
#      12     if res.status_code == 200:
#      13         print(json.dumps(res.json(), indent=4))
#
# NameError: name 'url' is not defined
